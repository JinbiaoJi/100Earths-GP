# %%
import numpy as np
import matplotlib.pyplot as plt
import george

# %% [markdown]
# ### 1. Generating some fake data (from a sinusoidal model) with error bars:

# %% [markdown]
# A sinusoidal model: $y = \mathrm{sin}(x)$
#
# Period: $P = 2\pi = 6.28$, Amplitude: $1$, Error: $0.2$

# %%
np.random.seed(1234)
x = 10 * np.sort(np.random.rand(15)) # 10 random points from 0 to 10.
yerr = 0.2 * np.ones_like(x)  #Error is 0.2
y = np.sin(x) + yerr * np.random.randn(len(x))

plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.xlim(0, 10)
plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y");

# %% [markdown]
# ### 2. Choose the exponential suqared kernel.
# $k\left(r^{2}\right)=\exp \left(-\frac{r^{2}}{2}\right)$
#
# $ k_{i, j}=A \exp \left(-\frac{\left(x_{i}-x_{j}\right)^{2}}{2 l^{2}}\right)$. Long term rising trend.
#
# $A$ > 0 is the amplitude of covariance, $l$ is the lengthscale of exponential decay, and $x_i− x_j$ is the separation between data points.
#
# If $l$ is large, two data points far apart in $x$ will be tightly correlated, and if small they will be loosely correlated.

# %%
from george import kernels
from george import GP
from george import modeling
from scipy.optimize import minimize

def Exp2fit(constant_guess = 5., metric_guess = 6.):
#     constant_guess = 5. # Amplitude of squared-exponential decorrelation kernel
#     metric_guess = 6. # Decorrelation timescale SQUARED

    kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
    gp = george.GP(kexp2, fit_kernel= True)
    gp.compute(x,yerr)

    x_pred = np.linspace(0, 10, 500)
    pred, pred_var = gp.predict(y, x_pred, return_var=True)
    print("Initial ln-likelihood: {0:.2f}".format(gp.log_likelihood(y)))
    
    plt.figure()
    plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
    plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
    plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
    plt.xlim(0, 10)
    plt.ylim(-1.45, 1.45)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title('A = {}, Metric ={}'.format(constant_guess,metric_guess))
    plt.legend();

# %% [markdown]
# ### 3. Test different initial parameters.

# %% [markdown]
# #### Use gp.compute(x, yerr)
# :param yerr: (optional) ``(nsamples,)`` or scalar
#     - The Gaussian uncertainties on the data points at coordinates
#     ``x``. These values will be added in quadrature to the diagonal of
#     the covariance matrix.

# %%
Exp2fit(1,100);Exp2fit(1,10);Exp2fit(1,1);Exp2fit(1,0.1);Exp2fit(50,10);
Exp2fit(100,10)
# Out:
# Initial ln-likelihood: -79.41
# Initial ln-likelihood: -23.08
# Initial ln-likelihood: -10.98
# Initial ln-likelihood: -16.04
# Initial ln-likelihood: -14.49
# Initial ln-likelihood: -15.81

# %% [markdown]
# #### gp.compute(x, yerr) -> gp.compute(x)

# %%
Exp2fit(1,100);Exp2fit(1,10);Exp2fit(1,1);Exp2fit(1,0.1);Exp2fit(50,10);
Exp2fit(100,10)
# Out:
# Initial ln-likelihood: -197151516699.62
# Initial ln-likelihood: -173553408737.39
# Initial ln-likelihood: -3119994.08
# Initial ln-likelihood: -35.40
# Initial ln-likelihood: -136360266452.07
# Initial ln-likelihood: -133051691824.17

# %% [markdown]
# ### 4. Minimization - fit for the maximum likelihood parameters:

# %%
def neg_ln_like(p):
    gp.set_parameter_vector(p)
    return -gp.log_likelihood(y, quiet=True) 
'''
Parameter: quiet: If ``True`` return negative infinity instead of raising 
an exception when there is an invalid kernel or 
linear algebra failure. (default: ``False``)
'''
def grad_neg_ln_like(p):
    gp.set_parameter_vector(p)
    return -gp.grad_log_likelihood(y, quiet=True)

def maxlik(constant_guess = 5., metric_guess = 6.):
#     constant_guess = 5. # Amplitude of squared-exponential decorrelation kernel
#     metric_guess = 6. # Decorrelation timescale SQUARED

    kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
    gp = george.GP(kexp2, fit_kernel= True)
    gp.compute(x,yerr)

    result = minimize(neg_ln_like, gp.get_parameter_vector(), jac=grad_neg_ln_like)
    print(result['x'])
    return result['x']

# %% [markdown]
# #### 4.1 Test minimization function:

# %% [markdown]
# #### Maximum likelihood parameters:

# %%
# Different initial parameters:
maxlik(5,6); maxlik(1,10); maxlik(100,0.1); maxlik(100,100);maxlik(100,100000);
# Out:
# [-0.48730534  0.60407602]
# [-0.48730646  0.60407403]
# [-0.48730529  0.60407586]
# [-0.48730533  0.60407543]
# [-0.48730185  0.60407985]

# %%
print('The parameters in log scale right now are: ',gp.get_parameter_vector())
# Out:
# The parameters right now are:  [-0.48730185  0.60407985]

# %%
pred, pred_var = gp.predict(y, x_pred, return_var=True)
plt.figure()
plt.fill_between(x_pred, pred - np.sqrt(pred_var), pred + np.sqrt(pred_var),
                color="k", alpha=0.2)
plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
plt.xlim(0, 10)
plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y")
plt.title('A = {:.2F}, Metric ={:.2F}'.format(np.exp(gp.get_parameter_vector()[0]),np.exp(gp.get_parameter_vector()[1])))
plt.legend();

# %% [markdown]
# #### 4.2 gp.compute(x,yerr):

# %%
constant_guess = 5 #ln(5) = 1.6094
metric_guess = 4   #ln(4) = 1.386
kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
gp = george.GP(kexp2, fit_kernel= True)
gp.compute(x,yerr)
print('Inital parameterts in log scale: \t \t{}'.format(gp.get_parameter_vector()))

result = minimize(neg_ln_like, gp.get_parameter_vector(), jac=grad_neg_ln_like)
print('Maximum likelihood parameters in log scale: \t{}'.format(result['x']))
# Out:
# Inital parameterts: 	 	[1.60943791 1.38629436]
# Maximum likelihood parameters: 	[-0.48730716  0.60407658]

# %% [markdown]
# #### 4.3 gp.compute(x):

# %%
constant_guess = 5 #ln(5) = 1.6094
metric_guess = 6   #ln(4) = 1.386
kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
gp = george.GP(kexp2, fit_kernel= True)
gp.compute(x)
print('Inital parameterts: \t \t{}'.format(gp.get_parameter_vector()))

result = minimize(neg_ln_like, gp.get_parameter_vector(), jac=grad_neg_ln_like)
print('Maximum likelihood parameters: \t{}'.format(result['x']))

#------------------------------------
#Plot the model
x_pred = np.linspace(0, 10, 500)
pred, pred_var = gp.predict(y, x_pred, return_var=True)
plt.figure()
plt.fill_between(x_pred, pred - np.sqrt(pred_var), pred + np.sqrt(pred_var),
                color="k", alpha=0.2)
plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
plt.xlim(0, 10)
plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y")
plt.title('A = {:.2F}, Metric ={:.2F}'.format(np.exp(gp.get_parameter_vector()[0]),np.exp(gp.get_parameter_vector()[1])))
plt.legend();
# Out:
# Inital parameterts: 	 	[1.60943791 1.79175947]
# Maximum likelihood parameters: 	[25.20722556  1.12211811]
# /Users/jinbiao.ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()

# %% [markdown]
# <font color='red'> Note: </font>It seems that the errors have to be input in the model.

# %% [markdown]
# ### 5. larger data sets.

# %%
np.random.seed(1214)
x =  50* np.sort(np.random.rand(60)) # 60 random points
yerr = 0.2 * np.ones_like(x)  #Error is 0.2
y = 1.5* np.sin(x) + yerr * np.random.randn(len(x))

plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.xlim(0, 50)
plt.ylim(-2.15, 2.15)
plt.xlabel("x")
plt.ylabel("y");

# %%
kexp2
# Out:
# ConstantKernel(log_constant=25.207225543412715, ndim=1, axes=array([0])) * ExpSquaredKernel(metric=Metric(3.0713527657009365, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)

# %%
def Exp2fit2(constant_guess = 5., metric_guess = 6.):
#     constant_guess = 5. # Amplitude of squared-exponential decorrelation kernel
#     metric_guess = 6. # Decorrelation timescale SQUARED

    kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
    gp = george.GP(kexp2, fit_kernel= True)
    gp.compute(x,yerr)

    x_pred = np.linspace(0, 50, 1500)
    pred, pred_var = gp.predict(y, x_pred, return_var=True)
    print("Initial ln-likelihood: {0:.2f}".format(gp.log_likelihood(y)))
    
    plt.figure()
    plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
    plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
    plt.plot(x_pred, 1.5* np.sin(x_pred), "--g", label = 'Original model')
    #plt.xlim(0, 10)
    #plt.ylim(-1.45, 1.45)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title('A = {}, Metric ={}'.format(constant_guess,metric_guess))
    plt.legend();

# %%
Exp2fit2(constant_guess= 2, metric_guess =20 ); Exp2fit2(1, 50); Exp2fit2(1, 1)
# Out:
# Initial ln-likelihood: -536.80
# Initial ln-likelihood: -686.19
# Initial ln-likelihood: -54.14

# %% [markdown]
# #### 5.1 Maximum likelihood parameters:

# %%
constant_guess = 5 #ln(5) = 1.6094
metric_guess = 10   #ln(4) = 1.386
kexp2 = constant_guess * kernels.ExpSquaredKernel(metric=metric_guess)
gp = george.GP(kexp2, fit_kernel= True)
gp.compute(x,yerr)
print('Inital parameterts: \t \t{}'.format(gp.get_parameter_vector()))
result = minimize(neg_ln_like, gp.get_parameter_vector(), jac=grad_neg_ln_like)
print('Maximum likelihood parameters: \t{}'.format(result['x']))
# Out:
# Inital parameterts: 	 	[1.60943791 2.30258509]
# Maximum likelihood parameters: 	[0.65878303 1.05862658]

# %%
x_pred = np.linspace(0, 50, 1500)
pred, pred_var = gp.predict(y, x_pred, return_var=True)
plt.figure()
plt.fill_between(x_pred, pred - np.sqrt(pred_var), pred + np.sqrt(pred_var),
                color="k", alpha=0.2)
plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
#plt.xlim(0, 10)
#plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y")
plt.title('A = {:.2F}, Metric ={:.2F}'.format(np.exp(gp.get_parameter_vector()[0]),np.exp(gp.get_parameter_vector()[1])))
plt.legend();

# %% [markdown]
# ### 6. Exponential-sine-squared kernel.

# %% [markdown]
# $$ k\left(\mathbf{x}_{i}, \mathbf{x}_{j}\right)=\exp \left(-\Gamma \sin ^{2}\left[\frac{\pi}{P}\left|x_{i}-x_{j}\right|\right]\right) $$
# $\cdot \text { gamma - The scale } \Gamma \text { of the correlations. }$
# $\cdot \text { log period - The log of the period } P \text { of the oscillation (in the same units as x). }$

# %%
def Expsinfit(constant_guess = 5., gamma_guess = 6., period = 6):
#     constant_guess = 5. # Amplitude of squared-exponential decorrelation kernel
#     metric_guess = 6. # Decorrelation timescale SQUARED

    kper = constant_guess * kernels.ExpSine2Kernel(gamma = gamma_guess, \
                                                   log_period= np.log(period))
    gp = george.GP(kper, fit_kernel= True)
    gp.compute(x,yerr)
    gp.
    x_pred = np.linspace(0, 50, 1500)
    pred, pred_var = gp.predict(y, x_pred, return_var=True)
    print("Initial ln-likelihood: {0:.2f}".format(gp.log_likelihood(y)))
    
    plt.figure()
    plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
    plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
    plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
    #plt.xlim(0, 10)
    #plt.ylim(-2.45, 2.45)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title('A = {}, Gamma ={}, period = {}'.format(constant_guess,gamma_guess,period))
    plt.legend();

# %% [markdown]
# #### 6.1 Test different priors.

# %%
Expsinfit(5,6,6); Expsinfit(5,0.1,6); Expsinfit(5,6,30); 
Expsinfit(2,6,30);Expsinfit(2,0.1,30);Expsinfit(5,0.1,30);
# Out:
# Initial ln-likelihood: -263.05
# Initial ln-likelihood: -307.62
# Initial ln-likelihood: -232.99
# Initial ln-likelihood: -247.30
# Initial ln-likelihood: -729.57
# Initial ln-likelihood: -726.31

# %% [markdown]
# #### 6.2 Maximum likelihood parameters:

# %%
constant_guess = 5.
gamma_guess = 6.
period = 6
kper = constant_guess * kernels.ExpSine2Kernel(gamma = gamma_guess, \
                                                   log_period= np.log(period))
gp = george.GP(kper, fit_kernel= True)
gp.compute(x,yerr)
print('Inital parameterts (log_amp, gamma, log_period):{}'.format(gp.get_parameter_vector()))

result = minimize(neg_ln_like, gp.get_parameter_vector(), \
                  jac=grad_neg_ln_like)
print('Maximum likelihood parameters: \t \t \t{}'.format(result['x']))
# Out:
# Inital parameterts (log_amp, gamma, log_period):[1.60943791 6.         1.79175947]
# Maximum likelihood parameters: 	 	 	[2.92692211 0.05862478 1.83826578]

# %%
x_pred = np.linspace(0, 50, 1500)
pred, pred_var = gp.predict(y, x_pred, return_var=True)
plt.figure()
plt.fill_between(x_pred, pred - np.sqrt(pred_var), pred + np.sqrt(pred_var),
                color="k", alpha=0.2)
plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
#plt.xlim(0, 10)
#plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y")
plt.title('A = {:.2F}, Gamma ={:.2F}, Period = {:.2f} '.format(np.exp(gp.get_parameter_vector()[0]), gp.get_parameter_vector()[1], \
                                              np.exp(gp.get_parameter_vector()[2])))
plt.legend();

# %% [markdown]
# #### 6.3 Test different minimization methods:

# %%
def maxmethod(constant_guess = 5., gamma_guess = 6., period = 6, method = None, jac=grad_neg_ln_like ):
    
    kper = constant_guess * kernels.ExpSine2Kernel(gamma = gamma_guess, \
                                                       log_period= np.log(period))
    gp = george.GP(kper, fit_kernel= True)
    gp.compute(x,yerr)
    #print('Inital parameterts (log_amp, gamma, log_period):{}'.format(gp.get_parameter_vector()))

    result = minimize(neg_ln_like, gp.get_parameter_vector(), \
                      jac=jac, method=method)
    print('Method: {:11}. Maximum likelihood parameters: {}'.format(method, result['x']))

# %%
maxmethod(5,6,6); maxmethod(5,0.1,6);maxmethod(5,0.1,60);maxmethod(5,6,60);maxmethod(5,6,600);maxmethod(5,60,6);
# Out:
# Method: None. Maximum likelihood parameters: [2.92692211 0.05862478 1.83826578]
# Method: None. Maximum likelihood parameters: [2.9269216  0.05862481 1.83826578]
# Method: None. Maximum likelihood parameters: [ 0.77054102 22.73035551  3.62966435]
# Method: None. Maximum likelihood parameters: [ 0.73755855 16.23599714  3.44714058]
# Method: None. Maximum likelihood parameters: [ 7.63557813e-02  2.38417789e+04 -7.52014777e+00]
# Method: None. Maximum likelihood parameters: [2.92692213 0.05862478 1.83826578]

# %%
amp = 5.; gamma = 5.; per = 6.
maxmethod(amp,gamma,per,'CG'); maxmethod(amp,gamma,per,'Nelder-Mead', None);
maxmethod(amp,gamma,per,'BFGS'); maxmethod(amp,gamma,per,'Newton-CG'); maxmethod(amp,gamma,per, 'L-BFGS-B');
maxmethod(amp,gamma,per,'TNC'); maxmethod(amp,gamma,per,'SLSQP');
maxmethod(amp,gamma,per,'COBYLA', None);
# Out:
# Method: CG         . Maximum likelihood parameters: [2.88253172 0.06121561 1.8385819 ]
# Method: BFGS       . Maximum likelihood parameters: [2.92692212 0.05862478 1.83826578]
# Method: Newton-CG  . Maximum likelihood parameters: [-0.51498439  3.92997537  1.83739546]
# Method: L-BFGS-B   . Maximum likelihood parameters: [-0.55047337  1.59883132  1.83686053]
# Method: TNC        . Maximum likelihood parameters: [-0.57201929  3.38694058  1.83749153]
# Method: SLSQP      . Maximum likelihood parameters: [  0.65641508 163.71289604   4.56813107]
# Method: Nelder-Mead. Maximum likelihood parameters: [2.92696775 0.05862211 1.83826574]
# Method: COBYLA     . Maximum likelihood parameters: [1.66346516 6.18820913 1.83808791]

# %%
maxmethod(amp,gamma,per,'Powell');
# Out:
# /Users/jinbiao.ji/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py:501: RuntimeWarning: Method Powell does not use gradient information (jac).
#   RuntimeWarning)
# /Users/jinbiao.ji/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# Method: Powell     . Maximum likelihood parameters: [2.69157338 0.07106194 1.82921611]

# %%
maxmethod(amp,gamma,per,'Powell')
# Out:
# Method: Powell    . Maximum likelihood parameters: [2.69157338 0.07106194 1.82921611]

# %%
gp.set_parameter_vector(result['x'])
gp.compute(x,yerr)

x_pred = np.linspace(0, 50, 1500)
pred, pred_var = gp.predict(y, x_pred, return_var=True)
plt.figure()
plt.fill_between(x_pred, pred - np.sqrt(pred_var), pred + np.sqrt(pred_var),
                color="k", alpha=0.2)
plt.plot(x_pred, pred, "k", lw=1.5, alpha=0.5, label = 'Fitted data')
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x_pred, np.sin(x_pred), "--g", label = 'Original model')
#plt.xlim(0, 10)
#plt.ylim(-1.45, 1.45)
plt.xlabel("x")
plt.ylabel("y")
plt.title('A = {:.2F}, Gamma ={:.2F}, Period = {:.2f} '.format(np.exp(gp.get_parameter_vector()[0]), gp.get_parameter_vector()[1], \
                                              np.exp(gp.get_parameter_vector()[2])))
plt.legend();
